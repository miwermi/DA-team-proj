# %%
# !pip install ipython-sql
# !pip install sqlalchemy
# Out:
# Collecting ipython-sql
#   Downloading ipython_sql-0.4.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: ipython>=1.0 in c:\users\heckr\anaconda3\envs\machinelearningenv\lib\site-packages (from ipython-sql) (7.31.1)
# Requirement already satisfied: six in c:\users\heckr\anaconda3\envs\machinelearningenv\lib\site-packages (from ipython-sql) (1.16.0)
# Collecting sqlparse
#   Downloading sqlparse-0.4.2-py3-none-any.whl (42 kB)
# Requirement already satisfied: sqlalchemy>=0.6.7 in c:\users\heckr\anaconda3\envs\machinelearningenv\lib\site-packages (from ipython-sql) (1.4.32)
# Requirement already satisfied: ipython-genutils>=0.1.0 in c:\users\heckr\anaconda3\envs\machinelearningenv\lib\site-packages (from ipython-sql) (0.2.0)
# Collecting prettytable<1
#   Downloading prettytable-0.7.2.zip (28 kB)
# Requirement already satisfied: matplotlib-inline in c:\users\heckr\anaconda3\envs\machinelearningenv\lib\site-packages (from ipython>=1.0->ipython-sql) (0.1.2)
# Requirement already satisfied: traitlets>=4.2 in c:\users\heckr\anaconda3\envs\machinelearningenv\lib\site-packages (from ipython>=1.0->ipython-sql) (5.1.1)
# Requirement already satisfied: decorator in c:\users\heckr\anaconda3\envs\machinelearningenv\lib\site-packages (from ipython>=1.0->ipython-sql) (5.1.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\heckr\anaconda3\envs\machinelearningenv\lib\site-packages (from ipython>=1.0->ipython-sql) (61.2.0)
# Requirement already satisfied: backcall in c:\users\heckr\anaconda3\envs\machinelearningenv\lib\site-packages (from ipython>=1.0->ipython-sql) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\heckr\anaconda3\envs\machinelearningenv\lib\site-packages (from ipython>=1.0->ipython-sql) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\heckr\anaconda3\envs\machinelearningenv\lib\site-packages (from ipython>=1.0->ipython-sql) (0.7.5)
# Requirement already satisfied: pygments in c:\users\heckr\anaconda3\envs\machinelearningenv\lib\site-packages (from ipython>=1.0->ipython-sql) (2.11.2)
# Requirement already satisfied: colorama in c:\users\heckr\anaconda3\envs\machinelearningenv\lib\site-packages (from ipython>=1.0->ipython-sql) (0.4.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\heckr\anaconda3\envs\machinelearningenv\lib\site-packages (from ipython>=1.0->ipython-sql) (3.0.20)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\heckr\anaconda3\envs\machinelearningenv\lib\site-packages (from jedi>=0.16->ipython>=1.0->ipython-sql) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\heckr\anaconda3\envs\machinelearningenv\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql) (0.2.5)
# Requirement already satisfied: importlib-metadata in c:\users\heckr\anaconda3\envs\machinelearningenv\lib\site-packages (from sqlalchemy>=0.6.7->ipython-sql) (4.11.3)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\heckr\anaconda3\envs\machinelearningenv\lib\site-packages (from sqlalchemy>=0.6.7->ipython-sql) (1.1.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\heckr\anaconda3\envs\machinelearningenv\lib\site-packages (from importlib-metadata->sqlalchemy>=0.6.7->ipython-sql) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\heckr\anaconda3\envs\machinelearningenv\lib\site-packages (from importlib-metadata->sqlalchemy>=0.6.7->ipython-sql) (4.1.1)
# Building wheels for collected packages: prettytable
#   Building wheel for prettytable (setup.py): started
#   Building wheel for prettytable (setup.py): finished with status 'done'
#   Created wheel for prettytable: filename=prettytable-0.7.2-py3-none-any.whl size=13714 sha256=bc5228489a88cc97d0ea36ffc1a180032d912b03536fc82b4fa1ab00795fadae
#   Stored in directory: c:\users\heckr\appdata\local\pip\cache\wheels\b2\7f\f6\f180315b584f00445045ff1699b550fa895d09471337ce21c6
# Successfully built prettytable
# Installing collected packages: sqlparse, prettytable, ipython-sql
# Successfully installed ipython-sql-0.4.1 prettytable-0.7.2 sqlparse-0.4.2
# Requirement already satisfied: sqlalchemy in c:\users\heckr\anaconda3\envs\machinelearningenv\lib\site-packages (1.4.32)
# Requirement already satisfied: importlib-metadata in c:\users\heckr\anaconda3\envs\machinelearningenv\lib\site-packages (from sqlalchemy) (4.11.3)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\heckr\anaconda3\envs\machinelearningenv\lib\site-packages (from sqlalchemy) (1.1.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\heckr\anaconda3\envs\machinelearningenv\lib\site-packages (from importlib-metadata->sqlalchemy) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\heckr\anaconda3\envs\machinelearningenv\lib\site-packages (from importlib-metadata->sqlalchemy) (3.7.0)

# %%
# !pip install psycopg2-binary
# Out:
# Collecting psycopg2-binary
#   Using cached psycopg2_binary-2.9.3-cp37-cp37m-win_amd64.whl (1.1 MB)
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.3

# %%
import os
import psycopg2 as ps
import pandas as pd
from config import db_host, db_port, db_name, db_user, db_password

# %%
connection = ps.connect(
    host=db_host,
    port=db_port,
    dbname=db_name,
    user=db_user,
    password=db_password)

# %%
boardgames_df = pd.read_sql_query("select * from bg_fulldata", con=connection)
boardgames_df.head()
# Out:
#    object_id                                      game_name  year_published  \
# 0     174430                                     Gloomhaven            2017
# 1     161936                      Pandemic Legacy  Season 1            2015
# 2     167791                              Terraforming Mars            2016
# 3     182028  Through the Ages  A New Story of Civilization            2015
# 4     224517                              Brass  Birmingham            2018
#
#    min_players  max_players  min_playtime  max_playtime     category_1  \
# 0            1            4            60           120      Adventure
# 1            2            4            60            60  Environmental
# 2            1            5           120           120       Economic
# 3            2            4           120           120           card
# 4            2            4            60           120       Economic
#
#         category_2       category_3  ...          category_5  \
# 0      Exploration          Fantasy  ...          Miniatures
# 1          Medical            error  ...               error
# 2    Environmental   industry_manuf  ...   Space Exploration
# 3     Civilization         Economic  ...               error
# 4   industry_manuf   Transportation  ...               error
#
#             category_6                         mech_1             mech_2  \
# 0                error  Campaign / Battle Card Driven   Cooperative Game
# 1                error                  Action Points   Cooperative Game
# 2   Territory Building                  Card Drafting   End Game Bonuses
# 3                error                  Action Points    Auction/Bidding
# 4                error                Hand Management             Income
#
#              mech_3            mech_4                       mech_5  \
# 0     Grid Movement   Hand Management                  Legacy Game
# 1   Hand Management       Legacy Game      Point to Point Movement
# 2   Hand Management            Income               Set Collection
# 3    Auction: Dutch     Card Drafting                       Income
# 4             Loans            Market   Network and Route Building
#
#                       mech_6 total_votes  users_rated
# 0              Modular Board         827        31254
# 1             Set Collection         549        34729
# 2                  Take That        1252        48339
# 3                        NaN         436        18269
# 4   Tech Trees / Tech Tracks         242        10070
#
# [5 rows x 21 columns]
